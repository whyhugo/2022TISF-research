# %%
import pandas as pd

# %%
data = pd.read_csv('correct.csv', index_col=0, encoding='utf-8')
data
# Out:
#         media name         media  \
# 0    BuzzFeed News  BuzzFeedNews
# 1    BuzzFeed News  BuzzFeedNews
# 2    BuzzFeed News  BuzzFeedNews
# 3    BuzzFeed News  BuzzFeedNews
# 4    BuzzFeed News  BuzzFeedNews
# ..             ...           ...
# 472  BuzzFeed News  BuzzFeedNews
# 473  BuzzFeed News  BuzzFeedNews
# 474  BuzzFeed News  BuzzFeedNews
# 475  BuzzFeed News  BuzzFeedNews
# 476  BuzzFeed News  BuzzFeedNews
#
#                                                   post  \
# 0    For people under guardianship, like Britney Sp...
# 1    "I knew I would be addressing you, my beloved ...
# 2    When it comes to treatment with monoclonal ant...
# 3    There’s a very American reason for why Prince ...
# 4    Scavino filed the lawsuit under his name after...
# ..                                                 ...
# 472  The pandemic has devoured time people wanted t...
# 473  The most potent instrument Swift plays on Red ...
# 474  “The idea of making a chronicle of such violen...
# ...

# %%
count = 0

a = [26 , 27 , 60 , 61 , 66 , 94 , 108 , 144 , 183 , 189 , 201 , 203 , 216 , 238 , 267 , 284 , 287 , 311 , 315 , 359 , 373 , 385 , 393 , 421 , 400 , 399 , 440 , 441 , 456 , 470 , 469 , 478 , 513 , 643 , 641 , 613 , 608 , 607 , 603 , 602 , 593 , 562 , 548 , 545]

for i in range(len(data)):
    if i in a :
        print(i)
        continue
    else:
        data.loc[count,'post2'] = data.loc[i,'post']
        count += 1
        
data
# Out:
# 26
# 27
# 60
# 61
# 66
# 94
# 108
# 144
# 183
# 189
# 201
# 203
# 216
# 238
# 267
# 284
# 287
# 311
# 315
# 359
# 373
# 385
# 393
# 399
# 400
# 421
# 440
# 441
# 456
# 469
# 470
# 478
# 513
# 545
# 548
# 562
# 593
# 602
# 603
# 607
# 608
# 613
# 641
# 643
#         media name         media  \
# 0    BuzzFeed News  BuzzFeedNews
# 1    BuzzFeed News  BuzzFeedNews
# 2    BuzzFeed News  BuzzFeedNews
# 3    BuzzFeed News  BuzzFeedNews
# 4    BuzzFeed News  BuzzFeedNews
# ..             ...           ...
# 646  BuzzFeed News  BuzzFeedNews
# 647  BuzzFeed News  BuzzFeedNews
# 648  BuzzFeed News  BuzzFeedNews
# 649  BuzzFeed News  BuzzFeedNews
# 650  BuzzFeed News  BuzzFeedNews
#
#                                                   post  \
# 0    For people under guardianship, like Britney Sp...
# 1    "I knew I would be addressing you, my beloved ...
# 2    When it comes to treatment with monoclonal ant...
# 3    There’s a very American reason for why Prince ...
# ...

# %%
for i in range(477,651):
    data = data.drop(i)
data
# Out:
#         media name         media  \
# 0    BuzzFeed News  BuzzFeedNews
# 1    BuzzFeed News  BuzzFeedNews
# 2    BuzzFeed News  BuzzFeedNews
# 3    BuzzFeed News  BuzzFeedNews
# 4    BuzzFeed News  BuzzFeedNews
# ..             ...           ...
# 472  BuzzFeed News  BuzzFeedNews
# 473  BuzzFeed News  BuzzFeedNews
# 474  BuzzFeed News  BuzzFeedNews
# 475  BuzzFeed News  BuzzFeedNews
# 476  BuzzFeed News  BuzzFeedNews
#
#                                                   post  \
# 0    For people under guardianship, like Britney Sp...
# 1    "I knew I would be addressing you, my beloved ...
# 2    When it comes to treatment with monoclonal ant...
# 3    There’s a very American reason for why Prince ...
# 4    Scavino filed the lawsuit under his name after...
# ..                                                 ...
# 472  The pandemic has devoured time people wanted t...
# 473  The most potent instrument Swift plays on Red ...
# 474  “The idea of making a chronicle of such violen...
# ...

# %%
data = data.drop('media name',axis=1)
data = data.drop('media',axis=1)
data = data.drop('link',axis=1)
#data = data.drop('time',axis=1)
data
# Out:
#                                                   post  \
# 0    For people under guardianship, like Britney Sp...
# 1    Satellite footage showed a massive plume of as...
# 2    The massive blast caused atmospheric shock wav...
# 3    Here are some of the most interesting and powe...
# 4    A viral TikTok had some people trying throat s...
# ..                                                 ...
# 497  The outbreak comes as the Omicron variant has ...
# 498                               Wait for the WIGGLE
# 499  There's no better way to say "I don't really l...
# 500  “I very much hope to one day have a family and...
# 501  “We know that millions of student loan borrowe...
#
#                                                article
# 0    \nAll three nightmares share a common cause: T...
# 1    \n\n\nA violent volcanic eruption on a South P...
# 2    \n\n\nThis week, we had the honor of speaking ...
# 3    \n\n\nPeople are posting on social media that ...
# ...

# %%
data.to_csv('correct.csv', encoding='utf_8')

# %%
import csv

with open('nytimes_with_post&article.csv', newline='', encoding="utf-8") as f:
    reader = csv.reader(f)
    data = list(reader)

print(data)

# %%
import csv 

data = pd.read_csv('nytimes_with_post&article.csv', index_col=0, encoding='utf-8')

data
# Out:
#                                                   post  \
# 0    991 homes were lost in the Marshall fire, one ...
# 1    Breaking News: Dozens of antigovernment protes...
# 2    Rep. Liz Cheney was the only Republican leader...
# 3    In the wake of the Jan. 6 attack on the Capito...
# 4    President Biden plans to call on the U.S. to r...
# ..                                                 ...
# 535  Desmond Tutu’s legacy, many said, was one of u...
# 536  As 2021 comes to a close, here's a roundup of ...
# 537  "Marriage requires amnesia, a mute button, a f...
# 538  Pictured here: snow removal from an antenna do...
# 539  Three members of the global K-pop phenomenon B...
#
#                                                article
# 0    LOUISVILLE, Colo. — Bryan Giles, who fled with...
# 1    MOSCOW — Troops from a Russia-led military all...
# 2    This episode contains strong language.  On the...
# 3    ​​One year ago, on the very same day when feve...
# ...

# %%
preds = []
temp = []
for i in range(len(data)):
    temp = []
    temp.append(data.loc[i,'post'])
    temp.append(data.loc[i,'article'])
    if i == 100:
        break
    preds.append(temp)
preds
# Out:
# [['991 homes were lost in the Marshall fire, one of the worst wildfires in Colorado history.',
# ...

# %%
df = data.reset_index(drop=True)

# %%
df.to_csv('nytimes_with_post&article.csv', encoding='utf_8')
