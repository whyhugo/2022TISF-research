# %%
import pandas as pd
import numpy as np

data1 = pd.read_csv('competition_test_bodies.csv', index_col=0, encoding='utf-8')
data2 = pd.read_csv('competition_test_stances.csv', index_col=0, encoding='utf-8')
data3 = pd.read_csv('train_bodies.csv', index_col=0, encoding='utf-8')
data4 = pd.read_csv('train_stances.csv', index_col=0, encoding='utf-8')

# %%
data = data2.reset_index()
data = data.drop(data.index[0:19060])
data
# Out:
#                                                 Headline  Body ID     Stance
# 19060  Report: Woman who claimed to have third breast...     1373  unrelated
# 19061  Jasmine Tridevil: Woman with three breast deni...     1275  unrelated
# 19062  Egypt's Sisi Offered Abbas Creation of Palesti...     1200  unrelated
# 19063  Woman Adds Third Breast by Undergoing Surgery ...     1188  unrelated
# 19064  U.S., BRENT CRUDE CRUDE FUTURES EXTEND GAINS O...      439    discuss
# ...                                                  ...      ...        ...
# 25408  The success of the Affordable Care Act is a hu...     2582      agree
# 25409  The success of the Affordable Care Act is a hu...     2583    discuss
# 25410  The success of the Affordable Care Act is a hu...     2584   disagree
# 25411  The success of the Affordable Care Act is a hu...     2585   disagree
# 25412  The success of the Affordable Care Act is a hu...     2586      agree
#
# [6353 rows x 3 columns]

# %%
data.to_csv('MINI_competition_test_stances.csv', index=False, encoding='utf-8')
